# %% [markdown]
# #  <font face="courier"  ><center>  <font color=#39ff14 >AirBnB </font >

# %% [markdown]
# <font face="courier"  >This public dataset named AirBnB NYC 2019 includes all needed information to find out more about hosts, geographical availability, necessary metrics to make predictions and draw conclusions from New York, USA. Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present more unique, personalized way of experiencing the world. This dataset describes the listing activity and metrics in NYC, NY for 2019.

# %% [markdown]
# ##    <font face="courier"><center><font color=#34FFB6 > Data  distribution</font> and<font color=#34FFB6 >  Interpretation</font>
#
#  <font face="courier"  >preparing and validating data that is incomplete, inaccurate, irrelevant, corrupt or incorrectly formatted data.

# %%
# Importing pandas and numpy - data manipulation libraries
import pandas as pd 
import numpy as np

# Data Visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Airbnb NYC 2019.csv") # reading the CSV file
df.head() # presenting the first 5 values
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.tail(3) # persenting the last 3 values
# Out:
#              id                                               name   host_id  \
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 48892  Ilgar & Aysel           Manhattan          Harlem  40.81475  -73.94867
# 48893            Taz           Manhattan  Hell's Kitchen  40.75751  -73.99112
# 48894     Christophe           Manhattan  Hell's Kitchen  40.76404  -73.98933
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 48892  Entire home/apt    115              10                  0         NaN
# 48893      Shared room     55               1                  0         NaN
# 48894     Private room     90               7                  0         NaN
#
# ...

# %%
df.shape # it will tell us the amount of rows and columns
# Out:
# (48895, 16)

# %% [markdown]
# <font face="courier"> hence the dataset has 16 columns and 48895 rows

# %%
df.info() # info() tells us tons of information about our data frame like the shape (rows, columns), the data type of our features, and the memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.describe() # Descriptive statistics
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.isnull().sum() # checking the columns with null values
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# percent missing values
df.isnull().mean() * 100
# Out:
# id                                 0.000000
# name                               0.032723
# host_id                            0.000000
# host_name                          0.042949
# neighbourhood_group                0.000000
# neighbourhood                      0.000000
# latitude                           0.000000
# longitude                          0.000000
# room_type                          0.000000
# price                              0.000000
# minimum_nights                     0.000000
# number_of_reviews                  0.000000
# last_review                       20.558339
# reviews_per_month                 20.558339
# calculated_host_listings_count     0.000000
# availability_365                   0.000000
# dtype: float64

# %%
df["room_type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df["neighbourhood_group"].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df["neighbourhood"].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
df.nunique().to_frame(name = 'Unique Values') #series to dataframe
# Out:
#                                 Unique Values
# id                                      48895
# name                                    47905
# host_id                                 37457
# host_name                               11452
# neighbourhood_group                         5
# neighbourhood                             221
# latitude                                19048
# longitude                               14718
# room_type                                   3
# price                                     674
# minimum_nights                            109
# number_of_reviews                         394
# last_review                              1764
# reviews_per_month                         937
# calculated_host_listings_count             47
# availability_365                          366

# %%
# getting the counts of unique rows in the DataFrame.
df["neighbourhood_group"].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
# getting the counts of unique rows in the DataFrame.
df["room_type"].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
# getting the counts of unique rows in the DataFrame.
df["host_id"].value_counts()
# this shows that the some people may hold multiple properties
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: host_id, Length: 37457, dtype: int64

# %% [markdown]
# <font face="courier">this shows that the some people may hold multiple properties

# %%
# For categorical and numerical datatypes, it returns a subset of the dataframe
cat_df = df.select_dtypes(include=['object'])
num_df = df.select_dtypes(exclude=['object'])

# %%
print(cat_df.columns) # Categorical columns
cat_df
# Out:
# Index(['name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'last_review'],
#       dtype='object')
#                                                     name      host_name  \
# 0                     Clean & quiet apt home by the park           John
# 1                                  Skylit Midtown Castle       Jennifer
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      Elisabeth
# 3                        Cozy Entire Floor of Brownstone    LisaRoxanne
# 4       Entire Apt: Spacious Studio/Loft by central park          Laura
# ...                                                  ...            ...
# 48890    Charming one bedroom - newly renovated rowhouse        Sabrina
# 48891      Affordable room in Bushwick/East Williamsburg        Marisol
# 48892            Sunny Studio at Historical Neighborhood  Ilgar & Aysel
# 48893               43rd St. Time Square-cozy single bed            Taz
# ...

# %%
print(num_df.columns) # Numerical columns
num_df
# Out:
# Index(['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')
#              id   host_id  latitude  longitude  price  minimum_nights  \
# 0          2539      2787  40.64749  -73.97237    149               1
# 1          2595      2845  40.75362  -73.98377    225               1
# 2          3647      4632  40.80902  -73.94190    150               3
# 3          3831      4869  40.68514  -73.95976     89               1
# 4          5022      7192  40.79851  -73.94399     80              10
# ...         ...       ...       ...        ...    ...             ...
# 48890  36484665   8232441  40.67853  -73.94995     70               2
# 48891  36485057   6570630  40.70184  -73.93317     40               4
# 48892  36485431  23492952  40.81475  -73.94867    115              10
# ...

# %% [markdown]
# ## <center><font face="courier" color=#34FFB6 >Renaming columns

# %% [markdown]
# <font face="courier">The column "name" refers to the name assigned to the listing by the host, not the name of host or the neighbourhood

# %%
# name might create confusion so renaming it
df.rename(columns={'name':'listing_name'}, inplace=True)
df.head()
# Out:
#      id                                      listing_name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ## <center><font face="courier" color=#34FFB6 > Data Type Correction

# %%
# As the last_review should be a date-Time not int so changing datatype
df['last_review'] = pd.to_datetime(df['last_review'], format='%Y-%m-%d')
df['last_review'].dtype.type
# Out:
# numpy.datetime64

# %% [markdown]
# ## <center><font face="courier"><font color=#39ff14 > Missing values</font> visualization

# %%
# showing the missing values
plt.figure(figsize=(10, 5))
sns.heatmap(df.isnull(), yticklabels=False, cmap='viridis_r', cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <font face="courier">showing that the <font color=#39ff14 >last_review</font> and <font color=#34FFB6  >reviews_per _month</font> have significant amounts of missing values
# purple color showing the missing values
#     <br>

# %% [markdown]
# # <center><font face="courier"><font color=#39ff14 > Imputing</font> the values

# %%
# Total missing values
df.isnull().sum()
# Out:
# id                                    0
# listing_name                         16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.isnull().mean()*100 # this gives us the % of missing values
# Out:
# id                                 0.000000
# listing_name                       0.032723
# host_id                            0.000000
# host_name                          0.042949
# neighbourhood_group                0.000000
# neighbourhood                      0.000000
# latitude                           0.000000
# longitude                          0.000000
# room_type                          0.000000
# price                              0.000000
# minimum_nights                     0.000000
# number_of_reviews                  0.000000
# last_review                       20.558339
# reviews_per_month                 20.558339
# calculated_host_listings_count     0.000000
# availability_365                   0.000000
# dtype: float64

# %% [markdown]
# ##### <font face="courier" > We leave missing values of host_name as it is because we can neither impute them nor drop them as the amount of missing values are insignificant

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ###  <font face="courier"  > Q Assigning the null values for <font color=#34FFB6>listing_names</font> as the <font color=#39ff14 >neighbourhood</font> values for easier identification<font>

# %% [markdown]
#  <font face="courier"  >As the listing names arent assigned, so we fill them using the neighbourhood name that they reside in till the host comes up with a new name

# %%
df["listing_name"] = df["listing_name"].fillna(df["neighbourhood"])

# %% [markdown]
# ###  <font face="courier"  > Q The minimum amount of reviews are <font color=#34FFB6 > 0</font> but the minimum reviews per month is <font color=#39ff14 > 0.01</font>

# %% [markdown]
# <font face="courier"  >As this isnt possible that total reviews are zero but the reviews per month is 0.01 so we replace the null values in <font color=#34FFB6 >reviews_per_month</font> by 0

# %%
df.fillna({'reviews_per_month':0}, inplace=True) # replace null values in reviews_per_month with 0

# %%
df.isnull().sum() # this gives us the missing values
# Out:
# id                                    0
# listing_name                          0
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#              id                                       listing_name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   listing_name                    48895 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# <font face="courier"  >Here we havent dropped the <b>last_review</b> and <b>reviews_per_month</b> as
#
#   -  <font face="courier"  ><b>last_review</b> ​ may not be there for a new listing there will be no last review and it is not necessary that the few people that visited the listing will definately give reviews
#   - <font face="courier"  ><b>reviews_per_month</b> cant be calculated for new listings and the ones that havent been visited yet. So we imputed it by 0.
#
# <font face="courier"  >Dropping a column is the last resort. So considering that from <b>last_review</b> and <b>reviews_per_month</b> can give us some idea about the popularity of the listing among the AirBnB userbase so we wont be dropping these columns
#     <br><br>
# <i><font face="courier" > We leave missing values of host_name as it is because we can neither impute them nor drop them as the amount of missing values are insignificant

# %%
df.describe([.05, .15 , .90, .95, .97, .98, .99 ])
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 5%     1.222383e+06  8.155641e+05     40.646114    -74.003880     40.000000
# 15%    5.406169e+06  3.552711e+06     40.678131    -73.991350     55.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 90%    3.399094e+07  2.128114e+08     40.804890    -73.907810    269.000000
# 95%    3.525910e+07  2.417646e+08     40.825643    -73.865771    355.000000
# 97%    3.572748e+07  2.576775e+08     40.840136    -73.829748    450.000000
# 98%    3.598575e+07  2.623600e+08     40.851312    -73.810278    550.000000
# ...

# %% [markdown]
# <font face="courier"  >Here we are looking out for values that look out of place, such as
#  - <font face="courier"  >large difference between the mean and median
#  - <font face="courier"  >significant difference between the 5 & 15 percentiles
#  - <font face="courier"  >significant difference between the 90, 99 & 99 percentiles

# %% [markdown]
# <font face="courier"  >Things that we have observed
#  - <font face="courier"  >the minimum of price being 0(free)
#  - <font face="courier"  >price difference in 99%(799) & max(10000)
#  - <font face="courier"  >minimum nights being 1250(max), minimum stay lasting years
#  - <font face="courier"  >the max(60) of reviews_per_month still feels iffy as it means that the listing is getting almost 2 <font face="courier"  >reviews each day i.e., getting 60 people each month for a single property seems very unlikely
#
# <font face="courier"  >Things that dont seem to be outliers
#  - <font face="courier"  >while the max of number_of_review may seem out of place but it might not be as Airbnb algorithm may be <font face="courier"  >reccomending that listing to more people as most people seem to like it and it seems genuine
#  - <font face="courier"  >Max price may be of a house

# %% [markdown]
# ###  <font face="courier"  > we can cap the minimum nights stay to a year </font>

# %%
df[df["minimum_nights"]==1250].minimum_nights = 360

# %% [markdown]
# #  <font face="courier"  ><center><font  color=#39ff14  >UNIVARIATE ANALYSIS

# %% [markdown]
# ### <center><font face="courier"><font color=#34FFB6 >Room Types</font> Distribution

# %%
# Shares of room_types
plt.style.use('Solarize_Light2')

explode = (0, 0.1, 0)
df['room_type'].value_counts().plot(kind='pie', subplots=True,explode=explode,shadow=True,figsize=(5, 5),label='Room Type ',
                                        autopct='%.0f%%',)
# Out:
# array([<AxesSubplot:ylabel='Room Type '>], dtype=object)

# %% [markdown]
# <font face="courier"  > It seems like people prefer private rooms/home when compared to shared room

# %% [markdown]
# ### <center><font face="courier"><font color=#39ff14 >Neighbourhood Distribution

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(7,7))
plt.title("Neighbourhood Group")
g = plt.pie(df.neighbourhood_group.value_counts(), labels=df.neighbourhood_group.value_counts().index,autopct='%1.1f%%', startangle=180)
plt.show()

# %% [markdown]
# <font face="courier"  >Here we can see that Manhattan & Brooklyn have the majority and least being Staten Island<br>
#    In some cases, outliers depend on context. In our example, you see that Manhattan and Brooklyn has significantly more data than Staten Island. This doesn’t count as an outlier, since Manhattan and Brooklyn has a higher housing density as compared to Staten Island.

# %%
sns.countplot(df['neighbourhood_group'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(8,5)
plt.title('Neighbourhood Group')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Group')

# %% [markdown]
# <font face="courier"  >In Private Room again Manahattan leads the chart , followed by Queens and least is in bronx<br>
#     For entire homes/apartments Manhattan again leads the chart with Brooklyn and Bronx coming close 2nd & 3rd
#     Shared rooms are again dominated by Manhattan

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(16,8))
sns.countplot(df['calculated_host_listings_count'], palette="plasma", )
# Out:
# <AxesSubplot:xlabel='calculated_host_listings_count', ylabel='count'>

# %%
plt.figure(figsize=(8,8))
sns.distplot(np.log1p(df['price']))
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
#Using Univariate outlier graph
plt.figure(figsize=(5,5))
ax = sns.boxplot(x = np.log1p(df["price"]))
plt.show()
# use functions like log and try again

# %% [markdown]
# <font face="courier"  >Performing transformations(log) in the columns to get the outliers like 0 price

# %% [markdown]
# ###  <font face="courier"  > As we can see there are values that show 0 price, so correcting them </font>

# %%
df[df["price"]==0].fillna(df["price"].mean(),inplace= True)  # as price has some missing values

# %%
#Using Univariate outlier graph
plt.figure(figsize=(5,5))
ax = sns.boxplot(x = df["number_of_reviews"])
plt.show()

# %% [markdown]
# ### <font face="courier"  ><center><font color=#34FFB6 >Prediction<br>
#
# <font face="courier"  >Assumption - more price means less demand

# %%
plt.style.use('Solarize_Light2')
sns.barplot(data=avg_price_per_night , x='neighbourhood_group', y='avg_neighborhood_price')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='avg_neighborhood_price'>

# %%
plt.style.use('ggplot')
sns.barplot(data=df , x='neighbourhood_group', y='reviews_per_month')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='reviews_per_month'>

# %% [markdown]
# <font face="courier"  >The prediction has shown us that the Manhattan which has the highest avg price has the lowest demand, but the same cant be said for Queens and Staten Island, they command 2nd and 3rd highest avg price but are high in demand

# %% [markdown]
# #  <font face="courier"  ><center><font color=#34FFB6 >BIVARIATE ANALYSIS

# %%
# The Average Price of the room per night based on the locality
avg_price_per_night= df.groupby(['neighbourhood_group','room_type'])['price'].mean().reset_index()
avg_price_per_night.rename(columns={'price': 'avg_neighborhood_price'}, inplace=True)
avg_price_per_night
# Out:
#    neighbourhood_group        room_type  avg_neighborhood_price
# 0                Bronx  Entire home/apt              127.506596
# 1                Bronx     Private room               66.788344
# 2                Bronx      Shared room               59.800000
# 3             Brooklyn  Entire home/apt              178.327545
# 4             Brooklyn     Private room               76.500099
# 5             Brooklyn      Shared room               50.527845
# 6            Manhattan  Entire home/apt              249.239109
# 7            Manhattan     Private room              116.776622
# 8            Manhattan      Shared room               88.977083
# 9               Queens  Entire home/apt              147.050573
# 10              Queens     Private room               71.762456
# 11              Queens      Shared room               69.020202
# 12       Staten Island  Entire home/apt              173.846591
# 13       Staten Island     Private room               62.292553
# ...

# %%
#plotting the group by data 
plt.style.use('Solarize_Light2')
sns.barplot(data=avg_price_per_night , x='room_type', y='avg_neighborhood_price', hue='neighbourhood_group')
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='avg_neighborhood_price'>

# %% [markdown]
# <font face="courier"  >
# In shared rooms , Manhattan leads , followed by Queens and staten Island has the least maximum price.
# We can say that Manhattan has the maximum average price in every type of room whereas bronx has the least maximum average price.

# %%
plt.style.use('ggplot')
plt.figure(figsize=(5,3))
sns.lmplot(x='reviews_per_month',y='price',hue='room_type',fit_reg=False,data=df)

# %% [markdown]
# <font face="courier"  >From this we can state that entire home/apartments are more expensive on average than private/shared rooms and arent booked/reviewed regularly, whereas the cheaper private/shared rooms are in higher demand as some have very high reviews permonth <br>
#
# <font face="courier"  >Also the private room with 60 reviews per month seems to be an <font color=#34FFB6 >outlier</font>, as one room cannot host multiple guest on such large scale

# %% [markdown]
# ###  <font face="courier"  > Capping the value of reviews per month at 30 for a private rooms, as a private room cant hold more than a person each night(as minimum nights to stay is 1) </font>

# %%
df[df["reviews_per_month"]==60].reviews_per_month = 30

# %% [markdown]
# ## <font face="courier"  ><center> Mapping

# %%
title = 'Neighbourhood Group Location'
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood_group).set_title(title)
plt.ioff()

title = 'Room type location per Neighbourhood Group'
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.room_type).set_title(title)
plt.ioff()

# %%
plt.figure(figsize=(8,6))
data_plot= sns.heatmap(df.corr(), cmap="magma", annot=True)
plt.show()

# %% [markdown]
# #### <font face="courier"> Here we can see that <font color=#34FFB6 >number_of _reviews</font> & <font color=#39ff14 >reviews_per_month</font> are related

# %% [markdown]
# <br>

# %% [markdown]
# # <font face="courier"><center><font color=#34FFB6 >Bivariate & Multivariate analysis

# %%
# boxplot of neighbourhood group and price
sns.boxplot(x="neighbourhood_group", y=np.log1p(df["price"]),hue = "room_type",data=df)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# <font face="courier">Boxplot of neighbourhood group and room type with availability
#
#  - <font face="courier">Brooklyn entire home/apt have the lowest availability/highest demand, followed by Manhattan's entire home/apt
#  - <font face="courier">Staten Island properties have the lowest demand
#  - <font face="courier">The most popular/high demand room type is private room and entire home/apt in most locations other than Staten Island and Bronx

# %%
# manhattan and brooklyn private room have the lowest availability/highest demand overall
sns.boxplot(x="neighbourhood_group", y="availability_365",hue = "room_type",data=df)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
#  <font face="courier">manhattan and brooklyn private room have the lowest availability/highest demand overall

# %%
sns.pairplot(df.drop(['latitude','longitude'],axis=1))

# %%
def Neighbourhood_price(df):
    
    plt.figure(figsize = [8,6])

    ax = sns.pointplot(data = df, x = 'room_type', y = 'price', hue = 'neighbourhood_group')
    ax.set_yticklabels([0,400,50], minor = True)
    plt.title('The price range in every neighbourhood group for every room type', fontsize = 16)
    plt.xlabel('Room Type',fontsize = 14)
    plt.ylabel('Price', fontsize = 14)
    ax.set_ylim(0,400)
    ax.set_yticks(range(0,450, 50))
    plt.show();

# %% [markdown]
# <font face="courier">This function shows a visualization for the relationship between price, neighbourhood group, and room type
#
# <font face="courier">    inputs:
#     df -> the cleaned dataframe
#     outputs:
#     the line visualization

# %%
Neighbourhood_price(df)

# %% [markdown]
# <font face="courier">price patterns for each Neighbourhood Group

# %%
plt.figure(figsize=(15,20))
sns.catplot(x="price", y="neighbourhood_group", hue="room_type", data=df[df['price'] <= 500], kind='violin',height=10)
plt.rcParams.update({'font.size': 12})

# %% [markdown]
# <font face="courier"><b>observation</b>-:<br>
# 1.) There are many new unvisited listings(almost 20%)<br>
# 2.) Maximum people have 1 property but some have properties in hundreds   <br>
# 3.) Here we can see that Manhattan & Brooklyn have the majority of listings and least being Staten Island<br>
# 4.) It seems like people prefer private rooms/home when compared to shared room<br>
# 5.) Here we can see that number_of _reviews & reviews_per_month are related<br>
# 6.) In Entire home/apt , Manhattan has the maximum average price, followed by staten Island and least is in Bronx<br>
# 7.) In Private Room again Manahattan leads the chart , followed by Queens and least is in bronx, for entire homes/apartments, Manhattan again leads the chart with Brooklyn and Bronx coing close 2nd & 3rd, shared rooms are again dominated by Manhattan<br>
# 8.) In shared rooms , Manhattan leads , followed by Queens and staten Island has the least maximum price.<br>
# We can say that Manhattan has the maximum average price in every type of room whereas bronx has the least maximum average price.<br>
# 9.) Staten Island properties have the lowest demand<br>
# 10.) The most popular/high demand room type is private room and entire home/apt in most locations other than Staten Island and Bronx<br>
# 11.) Manhattan and brooklyn private room have the lowest availability/highest demand overall<br>
# 12.) The neighborhood, room type, and number of listings owned all have a relationship with the price of a listing<br>

# %% [markdown]
# ### <font face="courier"  ><font color=#34FFB6 >Prediction
#
# <font face="courier"  >Assumption - More price means less demand<br>
#     conclusion - The prediction has shown us that the Manhattan which has the highest avg price has the lowest demand, but the same cant be said for Queens and Staten Island, they command 2nd and 3rd highest avg price but are high in demand

# %% [markdown]
# ### <font face="courier"> made by Brajeshwar Thakur

# %% [markdown]
# # <center>Hypothesis testing

# %%
df_copy = df

# %%
df_copy.loc[df_copy['room_type'] == 'Entire home/apt', 'home'] = True
df_copy.loc[df_copy['room_type'] != 'Entire home/apt', 'home'] = False

# %%
df_hyp = df_copy[['home','availability_365']]
df_hyp.head()
# Out:
#     home  availability_365
# 0  False               365
# 1   True               355
# 2  False               365
# 3   True               194
# 4   True                 0

# %%
home = df_hyp['availability_365'][df_hyp['home']==True]
non_home = df_hyp['availability_365'][df_hyp['home']==False]
